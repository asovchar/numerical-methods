# %% [markdown]
# ### Виконав: Овчар Антон, КА-64
# # Лабораторна робота №8
# ## Крайова задача другого порядку
# #### 1. Умова
# Розв'язати крайову задачу
# $ \begin{cases}
# Ay=f(x), \quad x_1<x<x_2 \\
# a_1y(x), \qquad\quad x=x_1 \\
# a_2y(x), \qquad\quad x=x_2
# \end{cases}
# \quad, де \quad Ay=y''+2xy'-2y, \quad a_1y=y'(2), \quad a_2y=0.4y(2.3)-y'(2.3)$
# #### 2.  Аналітичний розв'язок
# Розв'язком задачі є функція:
#
# $\quad y=1.172x^2-0.777x+1.556+(0.939x+0.66)^{-1}$
#
# Диференціальні оператори мають вигляд:
#
# $\quad Ay=2.344x^2-0.768-\frac{2}{0.939x+0.66}-\frac{1.878x}{(0.939x+0.66)^2}+\frac{1.763}{(0.939x+0.66)^3} \\
# \quad a_1y=3.765\\
# \quad a_2y=-1.967
# $
# #### 3. Чисельний розв'язок

# %%
import numpy as np
import pandas as pd
from IPython.display import display, HTML
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (15.0, 7.5) # set default size of plots

# %% [markdown]
# ##### Умова задачі

# %%
A = 1.172
B = -0.777
C = 1.556
D = 0.939
E = 0.66
x0 = 2
xn = 2.3

def y(x):
    return A*x**2 + B*x + C + (D*x + E)**(-1)

def dy(x):
    return 2*A*x + B - D*(D*x + E)**(-2)

def d2y(x):
    return 2*A + 2*D**2*(D*x + E)**(-3)

def p(x):
    return 2*x

def q(x):
    return -2

def f(x):
    return d2y(x) + p(x) * dy(x) + q(x) * y(x)

def a1(x=x0):
    return dy(x)

def alpha():
    return -1

def beta():
    return 0.4

def a2(x=xn):
    return alpha() * dy(x) + beta() * y(x)

def f1(x):
    return a1() * y(x)

def f2(x):
    return a2() * y(x)

# %% [markdown]
# ##### Метод скінченних різниць

# %%
def get_matrix(x0, xn, n):
    h = (xn - x0) / n
    x = np.array([x0+i*h for i in range(n+1)])
    result = np.zeros((n+1, n+1))
    answer = np.zeros(n+1)
    
    for i in range(0, n+1):
        if i == 0:
            result[i][i] = -2 / h**2 + q(x[i])
            result[i][i+1] = 2 / h**2
            answer[i] = f(x[i]) + 2 * a1() * (1 / h - p(x[i]) / 2)
        elif i == n:
            result[i][i-1] = 2 / h**2
            result[i][i] = -2 / h**2 + q(x[i]) - 2 * beta() / alpha() * (1 / h + p(x[i]) / 2)
            answer[i] = f(x[i]) - 2 * a2() / alpha() * (1 / h + p(x[i]) / 2)
        else:
            result[i][i-1] = 1 / h**2 - p(x[i]) / 2 / h
            result[i][i] = -2 / h**2 + q(x[i])
            result[i][i+1] = 1 / h**2 + p(x[i]) / 2 / h
            answer[i] = f(x[i])
    
    return result, answer

# %% [markdown]
# ##### Метод прогонки

# %%
def solve(matr_copy, vect_copy):
    matr = np.copy(matr_copy)
    vect = np.copy(vect_copy)
    n = matr.shape[0]
    a = [matr[i+1][i] for i in range(n-1)]
    a.insert(0, 0)
    b = [matr[i][i+1] for i in range(n-1)]
    b.append(0)
    c = [matr[i][i] for i in range(n)]
    f = vect
    
    x = [0 for i in range(n)]
    for i in range(1, n):
        m = a[i] / c[i-1]
        c[i] = c[i] - m * b[i-1]
        f[i] = f[i] - m * f[i-1]
    x[n-1] = f[n-1]/c[n-1]
    for i in range(n-2, -1, -1):
        x[i] = (f[i] - b[i] * x[i+1]) / c[i]
        
    return x

# %% [markdown]
# ##### Результати роботи програми

# %%
N = 500
matr, vect = get_matrix(x0, xn, N)
res = solve(matr, vect)
table = pd.DataFrame({
    'X': [x0+i*(xn-x0)/N for i in range(N+1)],
    'Y (method)': res,
    'Y (actual)': [y(x0+i*(xn-x0)/N) for i in range(N+1)],
    'Error': [np.fabs(res[i] - y(x0+i*(xn-x0)/N)) for i in range(N+1)]
})
display(table)
# Out:
#           X  Y (method)  Y (actual)         Error
# 0    2.0000    5.084011    5.084011  3.183203e-09
# 1    2.0006    5.086271    5.086271  3.187513e-09
# 2    2.0012    5.088531    5.088531  3.191825e-09
# 3    2.0018    5.090792    5.090792  3.196137e-09
# 4    2.0024    5.093055    5.093055  3.200448e-09
# 5    2.0030    5.095318    5.095318  3.204759e-09
# 6    2.0036    5.097582    5.097582  3.209072e-09
# 7    2.0042    5.099847    5.099847  3.213385e-09
# 8    2.0048    5.102112    5.102112  3.217699e-09
# 9    2.0054    5.104379    5.104379  3.222014e-09
# 10   2.0060    5.106647    5.106647  3.226329e-09
# 11   2.0066    5.108915    5.108915  3.230640e-09
# 12   2.0072    5.111184    5.111184  3.234955e-09
# 13   2.0078    5.113454    5.113454  3.239272e-09
# 14   2.0084    5.115725    5.115725  3.243588e-09
# 15   2.0090    5.117997    5.117997  3.247902e-09
# 16   2.0096    5.120270    5.120270  3.252218e-09
# 17   2.0102    5.122544    5.122544  3.256532e-09
# 18   2.0108    5.124818    5.124818  3.260848e-09
# 19   2.0114    5.127094    5.127094  3.265163e-09
# 20   2.0120    5.129370    5.129370  3.269479e-09
# 21   2.0126    5.131647    5.131647  3.273795e-09
# 22   2.0132    5.133926    5.133926  3.278109e-09
# 23   2.0138    5.136205    5.136205  3.282426e-09
# 24   2.0144    5.138484    5.138484  3.286742e-09
# 25   2.0150    5.140765    5.140765  3.291057e-09
# 26   2.0156    5.143047    5.143047  3.295375e-09
# 27   2.0162    5.145329    5.145329  3.299691e-09
# 28   2.0168    5.147613    5.147613  3.304010e-09
# 29   2.0174    5.149897    5.149897  3.308328e-09
# ..      ...         ...         ...           ...
# 471  2.2826    6.245562    6.245562  5.192579e-09
# 472  2.2832    6.248235    6.248235  5.196710e-09
# 473  2.2838    6.250909    6.250909  5.200838e-09
# 474  2.2844    6.253583    6.253583  5.204968e-09
# 475  2.2850    6.256259    6.256259  5.209094e-09
# 476  2.2856    6.258935    6.258935  5.213221e-09
# 477  2.2862    6.261612    6.261612  5.217347e-09
# 478  2.2868    6.264290    6.264290  5.221473e-09
# 479  2.2874    6.266969    6.266969  5.225597e-09
# 480  2.2880    6.269649    6.269649  5.229720e-09
# 481  2.2886    6.272330    6.272330  5.233840e-09
# 482  2.2892    6.275011    6.275011  5.237964e-09
# 483  2.2898    6.277694    6.277694  5.242083e-09
# 484  2.2904    6.280377    6.280377  5.246201e-09
# 485  2.2910    6.283061    6.283061  5.250320e-09
# 486  2.2916    6.285746    6.285746  5.254439e-09
# 487  2.2922    6.288432    6.288432  5.258556e-09
# 488  2.2928    6.291119    6.291119  5.262670e-09
# 489  2.2934    6.293806    6.293806  5.266788e-09
# 490  2.2940    6.296495    6.296495  5.270902e-09
# 491  2.2946    6.299184    6.299184  5.275014e-09
# 492  2.2952    6.301874    6.301874  5.279128e-09
# 493  2.2958    6.304565    6.304565  5.283240e-09
# 494  2.2964    6.307257    6.307257  5.287347e-09
# 495  2.2970    6.309950    6.309950  5.291458e-09
# 496  2.2976    6.312644    6.312644  5.295568e-09
# 497  2.2982    6.315339    6.315339  5.299674e-09
# 498  2.2988    6.318034    6.318034  5.303779e-09
# 499  2.2994    6.320730    6.320730  5.307885e-09
# 500  2.3000    6.323428    6.323428  5.311990e-09
#
# [501 rows x 4 columns]

# %% [markdown]
# ##### Графік залежності помилки від розміру кроку дискретизації

# %%
steps = []
errors = []
for j in range(2, 1000):
    N = j
    matr, vect = get_matrix(x0, xn, N)
    res = solve(matr, vect)
    steps.append((xn-x0)/N)
    errors.append(max(np.fabs([res[i] - y(x0+i*(xn-x0)/N) for i in range(N+1)])))
table = pd.DataFrame(steps, errors)
display(table)
# Out:
#                      0
# 3.566444e-04  0.150000
# 1.542246e-04  0.100000
# 8.595832e-05  0.075000
# 5.478368e-05  0.060000
# 3.795854e-05  0.050000
# 2.785018e-05  0.042857
# 2.130412e-05  0.037500
# 1.682280e-05  0.033333
# 1.362063e-05  0.030000
# 1.125315e-05  0.027273
# 9.453498e-06  0.025000
# 8.053544e-06  0.023077
# 6.943096e-06  0.021429
# 6.047484e-06  0.020000
# 5.314650e-06  0.018750
# 4.707406e-06  0.017647
# 4.198604e-06  0.016667
# 3.768058e-06  0.015789
# 3.400504e-06  0.015000
# 3.084229e-06  0.014286
# 2.810113e-06  0.013636
# 2.570987e-06  0.013043
# 2.361135e-06  0.012500
# 2.175967e-06  0.012000
# 2.011761e-06  0.011538
# 1.865464e-06  0.011111
# 1.734562e-06  0.010714
# 1.616979e-06  0.010345
# 1.510953e-06  0.010000
# 1.415026e-06  0.009677
# ...                ...
# 8.933965e-10  0.000309
# 1.596334e-09  0.000309
# 1.298377e-09  0.000309
# 1.323749e-09  0.000308
# 9.907444e-10  0.000308
# 1.557374e-09  0.000308
# 1.555411e-09  0.000307
# 1.564628e-09  0.000307
# 1.604309e-09  0.000307
# 9.320713e-10  0.000306
# 1.568841e-09  0.000306
# 1.636249e-09  0.000306
# 1.567596e-09  0.000305
# 1.514868e-09  0.000305
# 1.458143e-09  0.000305
# 1.419759e-09  0.000305
# 1.553444e-09  0.000304
# 1.603713e-09  0.000304
# 1.324571e-09  0.000304
# 1.316097e-09  0.000303
# 1.433207e-09  0.000303
# 1.269748e-09  0.000303
# 1.397573e-09  0.000302
# 1.439545e-09  0.000302
# 1.525414e-09  0.000302
# 1.670363e-09  0.000302
# 1.597035e-09  0.000301
# 1.748913e-09  0.000301
# 1.517330e-09  0.000301
# 1.401997e-09  0.000300
#
# [998 rows x 1 columns]

# %%
plt.plot(steps, errors)
plt.xlabel('Step Size')
plt.ylabel('Error')
plt.show()

# %% [markdown]
# #### Висновок
# Проаналізувавши отримані результати, ми можемо зробити висновки про те, що метод скінченних різниць дає достатньо точний розв’язок диференціальної задачі, оскільки похибка значень нашої функції порівняно зі значеннями аналітичного розв’язку задачі у тих же точках є відносно невеликою. При зменшенні розміру кроку зменшується і похибка.
